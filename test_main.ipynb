# %%
from rich.markdown import Markdown as RichMarkdown
from IPython.display import display

# %%
from src.utils.youtube import load_youtube_transcript, YouTubeTranscriptPreprocessor

# %%
youtube_url = "https://youtu.be/vtpjk1AjsH0?si=viI7UIVzr0wtgQfo"

# %%
preprocessor = YouTubeTranscriptPreprocessor()
docs = load_youtube_transcript(youtube_url)

# %%
docs
# Out:
# {'transcript': ['no transcript found']}

# %% [markdown]
# YOUTUBE TRANSCIPT

# %%
from src.application.usecases.youtube_summary import youtube_summary

# %%
result = await youtube_summary("https://youtu.be/vtpjk1AjsH0?si=viI7UIVzr0wtgQfo")
# Out:
# 200

# %%
md = RichMarkdown(result["final_summary"])
display(md)
# Out:
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃                                         Analisis Bisnis dan Fundamental                                         ┃
# ┗━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┛
#
# Pemahaman analisis bisnis dan fundamental sangat penting untuk memulai usaha atau berinvestasi. Dasar-dasar bisnis
# yang kuat menjadi kunci kesuksesan jangka panjang.
#
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃                                                  Alokasi Modal                                                  ┃
# ┗━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┛
#
# Alokasi modal yang efektif meliputi belanja modal, penelitian dan pengembangan, iklan, serta pembagian dividen.
# ...

# %% [markdown]
# SUMMARY

# %%
from src.application.usecases.calling_agent import call_agent
from src.application.AI.summary.summary_agent import summary_agent

# %%
params = {"contents": [doc.page_content for doc in content]}
result = await call_agent(agent=summary_agent, param=params)

# %%
result
# Out:
# {'contents': ['Oke, kali ini ya gua akan ngajarin lu semua sesuatu yang sedikit berbeda. Gimana caranya gua pribadi tuh analisa bisnis baik yang mau gua bikin atau yang mau gua investasikan. Jadi di sini lu akan gua ajarin gimana caranya nganalisa bisnis dari nol sampai lu beneran paham. Dan menurut gua video ini akan berharga ya untuk kalian mau seorang investor bisnis ya, mau kalian adalah seorang pengusaha, mau lu level 0, mau lu level karyaond pun gua yakin lu mau karya 1000. Ada hal yang lu bisa petik',
# ...

# %%
md = RichMarkdown(result["final_summary"])
display(md)
# Out:
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃                                         Analisis Bisnis dan Pendidikan                                          ┃
# ┗━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┛
#
# Pendidikan bisnis yang kuat sangat penting sebelum memulai usaha. Pemahaman tentang analisis bisnis, termasuk
# konsep dasar seperti laba bersih dan free cash flow, dapat mengurangi risiko kebangkrutan.
#
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃                                           Alokasi Modal dan Investasi                                           ┃
# ┗━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┛
#
# ...

# %% [markdown]
# REPORTER

# %%
from src.application.usecases.calling_agent import call_agent
from src.application.AI.research.research_agent import reporter_agent

# %%
topic = "Detailed report on how to build Agentic AI systems, design patterns and current frameworks"
params = {"topic": topic}
result = await call_agent(agent=reporter_agent, param=params)

# %%
result["final_report"]
# Out:
# '# Introduction\n\nAgentic AI systems represent a transformative advancement in artificial intelligence, characterized by their ability to operate autonomously and adapt to dynamic environments. Unlike traditional AI, which relies heavily on predefined rules and human oversight, Agentic AI systems learn from real-time data, making them more versatile and effective in various applications. This report aims to explore the fundamental aspects of Agentic AI, including their design patterns, current development frameworks, real-world applications, challenges, and future trends. By understanding these elements, we can better appreciate the significance of Agentic AI in shaping the future of technology and its potential impact across multiple industries.\n\n## Understanding Agentic AI Systems\n\n**Agentic AI systems are designed to operate autonomously, making decisions and taking actions based on their environment.** Unlike traditional AI systems, which typically rely on predefined rules a
# ...

# %%
md = RichMarkdown(result["final_report"])
display(md)
# Out:
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃                                                  Introduction                                                   ┃
# ┗━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┛
#
# Agentic AI systems represent a transformative advancement in artificial intelligence, characterized by their
# ability to operate autonomously and adapt to dynamic environments. Unlike traditional AI, which relies heavily on
# predefined rules and human oversight, Agentic AI systems learn from real-time data, making them more versatile and
# effective in various applications. This report aims to explore the fundamental aspects of Agentic AI, including
# their design patterns, current development frameworks, real-world applications, challenges, and future trends. By
# ...
